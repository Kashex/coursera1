# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# KASHFIA HAQUE full time mom/ chronic pain sufferer

# %% [markdown]
# _string_I am interested in data science because I want to join the health sector for research taking place investigating my health condition.

# %% [markdown]
# ### calculating 4+3

# %%
4 + 3
# Out:
# 7

# %% [markdown]
# | header | header |
# | ------ | ------ |
# | cell | cell |
#
# - header
#   - cell1
#   - cell2
#
#  <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
